# %% [markdown]
# # Name : Sandhana Chavan

# %% [markdown]
# # # task 3 GRIP@ The sparks foundation

# %% [markdown]
# # # GRIPJUNE2021

# %% [markdown]
# # data science and Business analytics

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn

# %% [markdown]
# # Read csv file

# %%
path = pd.read_csv(r'C:\Users\Sneha\Downloads\SampleSuperstore.csv')

# %%
 data = path

# %%
data
# Out:
#            Ship Mode    Segment        Country             City       State  \
# 0       Second Class   Consumer  United States        Henderson    Kentucky
# 1       Second Class   Consumer  United States        Henderson    Kentucky
# 2       Second Class  Corporate  United States      Los Angeles  California
# 3     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# ...              ...        ...            ...              ...         ...
# 9989    Second Class   Consumer  United States            Miami     Florida
# 9990  Standard Class   Consumer  United States       Costa Mesa  California
# 9991  Standard Class   Consumer  United States       Costa Mesa  California
# 9992  Standard Class   Consumer  United States       Costa Mesa  California
# 9993    Second Class   Consumer  United States      Westminster  California
#
#       Postal Code Region         Category Sub-Category     Sales  Quantity  \
# 0           42420  South        Furniture    Bookcases  261.9600         2
# 1           42420  South        Furniture       Chairs  731.9400         3
# 2           90036   West  Office Supplies       Labels   14.6200         2
# 3           33311  South        Furniture       Tables  957.5775         5
# 4           33311  South  Office Supplies      Storage   22.3680         2
# ...           ...    ...              ...          ...       ...       ...
# 9989        33180  South        Furniture  Furnishings   25.2480         3
# 9990        92627   West        Furniture  Furnishings   91.9600         2
# 9991        92627   West       Technology       Phones  258.5760         2
# 9992        92627   West  Office Supplies        Paper   29.6000         4
# 9993        92683   West  Office Supplies   Appliances  243.1600         2
#
#       Discount    Profit
# 0         0.00   41.9136
# 1         0.00  219.5820
# 2         0.00    6.8714
# 3         0.45 -383.0310
# 4         0.20    2.5164
# ...        ...       ...
# 9989      0.20    4.1028
# 9990      0.00   15.6332
# 9991      0.20   19.3932
# 9992      0.00   13.3200
# 9993      0.00   72.9480
#
# [9994 rows x 13 columns]

# %%
data.head()
# Out:
#         Ship Mode    Segment        Country             City       State  \
# 0    Second Class   Consumer  United States        Henderson    Kentucky
# 1    Second Class   Consumer  United States        Henderson    Kentucky
# 2    Second Class  Corporate  United States      Los Angeles  California
# 3  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4  Standard Class   Consumer  United States  Fort Lauderdale     Florida
#
#    Postal Code Region         Category Sub-Category     Sales  Quantity  \
# 0        42420  South        Furniture    Bookcases  261.9600         2
# 1        42420  South        Furniture       Chairs  731.9400         3
# 2        90036   West  Office Supplies       Labels   14.6200         2
# 3        33311  South        Furniture       Tables  957.5775         5
# 4        33311  South  Office Supplies      Storage   22.3680         2
#
#    Discount    Profit
# 0      0.00   41.9136
# 1      0.00  219.5820
# 2      0.00    6.8714
# 3      0.45 -383.0310
# 4      0.20    2.5164

# %%
data.shape
# Out:
# (9994, 13)

# %% [markdown]
# # getting data info

# %%
data.info
# Out:
# <bound method DataFrame.info of            Ship Mode    Segment        Country             City       State  \
# 0       Second Class   Consumer  United States        Henderson    Kentucky
# 1       Second Class   Consumer  United States        Henderson    Kentucky
# 2       Second Class  Corporate  United States      Los Angeles  California
# 3     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# ...              ...        ...            ...              ...         ...
# 9989    Second Class   Consumer  United States            Miami     Florida
# 9990  Standard Class   Consumer  United States       Costa Mesa  California
# 9991  Standard Class   Consumer  United States       Costa Mesa  California
# 9992  Standard Class   Consumer  United States       Costa Mesa  California
# 9993    Second Class   Consumer  United States      Westminster  California
#
#       Postal Code Region         Category Sub-Category     Sales  Quantity  \
# 0           42420  South        Furniture    Bookcases  261.9600         2
# 1           42420  South        Furniture       Chairs  731.9400         3
# 2           90036   West  Office Supplies       Labels   14.6200         2
# 3           33311  South        Furniture       Tables  957.5775         5
# 4           33311  South  Office Supplies      Storage   22.3680         2
# ...           ...    ...              ...          ...       ...       ...
# 9989        33180  South        Furniture  Furnishings   25.2480         3
# 9990        92627   West        Furniture  Furnishings   91.9600         2
# 9991        92627   West       Technology       Phones  258.5760         2
# 9992        92627   West  Office Supplies        Paper   29.6000         4
# 9993        92683   West  Office Supplies   Appliances  243.1600         2
#
#       Discount    Profit
# 0         0.00   41.9136
# 1         0.00  219.5820
# 2         0.00    6.8714
# 3         0.45 -383.0310
# 4         0.20    2.5164
# ...        ...       ...
# 9989      0.20    4.1028
# 9990      0.00   15.6332
# 9991      0.20   19.3932
# 9992      0.00   13.3200
# 9993      0.00   72.9480
#
# [9994 rows x 13 columns]>

# %%
data.describe()
# Out:
#         Postal Code         Sales     Quantity     Discount       Profit
# count   9994.000000   9994.000000  9994.000000  9994.000000  9994.000000
# mean   55190.379428    229.858001     3.789574     0.156203    28.656896
# std    32063.693350    623.245101     2.225110     0.206452   234.260108
# min     1040.000000      0.444000     1.000000     0.000000 -6599.978000
# 25%    23223.000000     17.280000     2.000000     0.000000     1.728750
# 50%    56430.500000     54.490000     3.000000     0.200000     8.666500
# 75%    90008.000000    209.940000     5.000000     0.200000    29.364000
# max    99301.000000  22638.480000    14.000000     0.800000  8399.976000

# %%
data['Country'].unique()
# Out:
# array(['United States'], dtype=object)

# %% [markdown]
# # Drop columns which are not necessary

# %%
data.drop(['Country','Postal Code'],axis=1,inplace=True)

# %%
sns.pairplot(data,hue='Region')

# %% [markdown]
# # Data visualisation

# %%
fig,axes=plt.subplots(1,1,figsize=(12,7))
sns.heatmap(data.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
sub = data.groupby("Sub-Category")["Quantity","Profit","Discount"]
# Out:
# <ipython-input-27-3ddaf70b29c6>:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   sub = data.groupby("Sub-Category")["Quantity","Profit","Discount"]

# %%
for g,gdata in sub:
  print(g)
  temp=sub.get_group(g)
  a=plt.figure(figsize=(13,8))
  plt.bar(temp['Quantity'],temp['Profit'])
  plt.xlabel('Quantity')
  plt.ylabel('Profit')
  plt.show()
  b=plt.figure(figsize=(13,8))
  plt.bar(temp['Quantity'],temp['Discount'])
  plt.xlabel('Quantity')
  plt.ylabel('Discount')
  plt.show()
# Out:
# Accessories
# Appliances
# Art
# Binders
# Bookcases
# Chairs
# Copiers
# Envelopes
# Fasteners
# Furnishings
# Labels
# Machines
# Paper
# Phones
# Storage
# Supplies
# Tables

# %%
ps=data.groupby('Sub-Category')['Sales','Profit'].sum()
ps
# Out:
# <ipython-input-32-9b80fa967234>:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   ps=data.groupby('Sub-Category')['Sales','Profit'].sum()
#                     Sales      Profit
# Sub-Category
# Accessories   167380.3180  41936.6357
# Appliances    107532.1610  18138.0054
# Art            27118.7920   6527.7870
# Binders       203412.7330  30221.7633
# Bookcases     114879.9963  -3472.5560
# Chairs        328449.1030  26590.1663
# Copiers       149528.0300  55617.8249
# Envelopes      16476.4020   6964.1767
# Fasteners       3024.2800    949.5182
# Furnishings    91705.1640  13059.1436
# Labels         12486.3120   5546.2540
# Machines      189238.6310   3384.7569
# Paper          78479.2060  34053.5693
# Phones        330007.0540  44515.7306
# Storage       223843.6080  21278.8264
# Supplies       46673.5380  -1189.0995
# Tables        206965.5320 -17725.4811

# %%
ps.plot.bar(color=['magenta','orange'],figsize=(16,9))
plt.title('profit vs sales')
plt.show()

# %%
group=data.groupby("Region",as_index=True)["Sales","Profit"].sum()
# Out:
# <ipython-input-34-2427a2d30289>:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   group=data.groupby("Region",as_index=True)["Sales","Profit"].sum()

# %%
group
# Out:
#                Sales       Profit
# Region
# Central  501239.8908   39706.3625
# East     678781.2400   91522.7800
# South    391721.9050   46749.4303
# West     725457.8245  108418.4489

# %%
group.plot.bar(color=["blue","yellow"])
# Out:
# <AxesSubplot:xlabel='Region'>

# %%
plt.bar(data["Ship Mode"],data["Sales"])
plt.xlabel("Ship Mode")
plt.ylabel("Sales")
plt.show()

# %%
plt.bar(data["Segment"],data["Sales"])
plt.xlabel("Segment")
plt.ylabel("Sales")
# Out:
# Text(0, 0.5, 'Sales')

# %%
Q=data.groupby("Region",as_index=False)[["Quantity"]].sum()
Q
# Out:
#     Region  Quantity
# 0  Central      8780
# 1     East     10618
# 2    South      6209
# 3     West     12266

# %%
plt.bar("Region","Quantity",data=Q)
plt.xlabel("Region")
plt.ylabel("Quantity")
# Out:
# Text(0, 0.5, 'Quantity')

# %%
d=data.groupby("Region",as_index=False)[["Quantity","Discount"]].sum()

# %%
sns.scatterplot("Quantity","Discount",data=d,hue="Region")
# Out:
# c:\users\sneha\appdata\local\programs\python\python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Quantity', ylabel='Discount'>

# %%
category=data.groupby("Category")[["Sales","Profit"]].sum()
category
# Out:
#                        Sales       Profit
# Category
# Furniture        741999.7953   18451.2728
# Office Supplies  719047.0320  122490.8008
# Technology       836154.0330  145454.9481

# %%
category.plot.bar(color=["pink","black"])
# Out:
# <AxesSubplot:xlabel='Category'>

# %%
city=data.groupby("City",as_index=False)[["Sales","Profit"]].sum()
city
# Out:
#             City     Sales     Profit
# 0       Aberdeen    25.500     6.6300
# 1        Abilene     1.392    -3.7584
# 2          Akron  2729.986  -186.6356
# 3    Albuquerque  2220.160   634.0881
# 4     Alexandria  5519.570   318.6183
# ..           ...       ...        ...
# 526   Woonsocket   195.550    78.6791
# 527      Yonkers  7657.666  2767.7557
# 528         York   817.978  -102.1692
# 529      Yucaipa    50.800    13.2080
# 530         Yuma   840.865  -465.9909
#
# [531 rows x 3 columns]

# %%
city[city["Sales"]==city["Sales"].max()]
# Out:
#               City       Sales      Profit
# 329  New York City  256368.161  62036.9837

# %%
city[city["Sales"]==city["Sales"].min()]
# Out:
#       City  Sales  Profit
# 1  Abilene  1.392 -3.7584

# %%
city[city["Profit"]==city["Profit"].min()]
# Out:
#              City       Sales      Profit
# 374  Philadelphia  109077.013 -13837.7674

# %%
state=data.groupby("State")[["Sales","Profit"]].sum()

# %%
state.plot.bar(color=["red","blue"],figsize=(20,8))
# Out:
# <AxesSubplot:xlabel='State'>

# %%
state[state["Sales"]==state["Sales"].max()]
# Out:
#                   Sales      Profit
# State
# California  457687.6315  76381.3871

# %%
state[state["Sales"]==state["Sales"].min()]
# Out:
#                Sales    Profit
# State
# North Dakota  919.91  230.1497

# %%
state[state["Profit"]==state["Profit"].max()]
# Out:
#                   Sales      Profit
# State
# California  457687.6315  76381.3871

# %%
state[state["Profit"]==state["Profit"].min()]
# Out:
#              Sales      Profit
# State
# Texas  170188.0458 -25729.3563

# %%
state[state["Profit"]<0]
# Out:
#                       Sales      Profit
# State
# Arizona          35282.0010  -3427.9246
# Colorado         32108.1180  -6527.8579
# Florida          89473.7080  -3399.3017
# Illinois         80166.1010 -12607.8870
# North Carolina   55603.1640  -7490.9122
# Ohio             78258.1360 -16971.3766
# Oregon           17431.1500  -1190.4705
# Pennsylvania    116511.9140 -15559.9603
# Tennessee        30661.8730  -5341.6936
# Texas           170188.0458 -25729.3563

# %% [markdown]
# # CONCLUSION

# %% [markdown]
# #1. New york city has highest/max sales(256368.161)
# 2. abilene city has low/min sales
# 3. Philadelphia has Low profits
# 4. California ha heighest profits
# 5. Texas has least profit
# 6. North Dakota has minimum sales
# 7. Least profit obtained from furniture.infact its facing loss
# 8. Office suplies has least sales
